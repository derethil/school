# %% [markdown]
# # Autoencoder for matrix imputation

# %% [markdown]
# In some cases our data contains missing values. In this exercise we will implement an autoencoder to impute the missing values.

# %% [markdown]
# <img src="ae_arch.png" width=600 height=400 />

# %% [markdown]
# As shown in the figure, the autoencoder receives as input the incomplete data and retrieves an imputed version after training.

# %% [markdown]
# The autoencoder is trained in a similar way as usual, but we need to masked the NaN values in the loss function
#
# $\mathcal{L} = \sum_{i,j: (i,j) \in S} (X_{ij} - \hat{X}_{ij})^{2}$. Notice that if your pixels are normalized between 0 and 1 you can also use binary cross entropy.
#
# The set $S$ are all the $(i,j)$ pairs with known entries.

# %% [markdown]
# Things to consider:
# - You have to mask some entries of the loss. Thus, you need to find the NaN entries and use their indices. Also make sure you use a loss that allows you to mask entries.
# - The NaN values in your input matrix should be transformed to zeros since the layers in torch does not handle NaN entries.

# %%
import numpy as np
import torchvision
from torchvision import transforms
import pandas as pd
import sklearn
import torch
from PIL import Image, ImageFilter 

import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import Dataset
import seaborn as sns
import pandas as pd

from tensorflow.keras.datasets import mnist

# %%
class MnistDigitsM():   
    def __init__(self, n_samples = 5000, perc_mask = 0.1):
        (train_images, Y_train), (test_images, Y_test) = mnist.load_data()
        train_images = train_images[:n_samples]
        inputs = train_images.reshape((n_samples, 784))/255.
        inputs = inputs[:n_samples]
        self.labels = Y_train[:n_samples]
        self.true_data = inputs.copy()
        inputs_flat = inputs.ravel()
        ind = np.arange(len(inputs_flat))
        ind_mask = np.random.choice(ind, int(ind.shape[0] * perc_mask))
        inputs_flat[ind_mask] = np.nan
        # mask perc_mask of data 
        self.data_train = inputs
        self.test_ind = np.where(np.isnan(inputs))

# %%
data = MnistDigitsM(perc_mask = 0.9)

# %%
data.data_train
# Out:
# array([[ 0., nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ...,  0., nan, nan],
#        [nan, nan,  0., ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan,  0., nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [ 0., nan, nan, ...,  0.,  0., nan]])

# %%
def plot_images(images, img_prow, width, length, title = None):
    '''
    Takes images as rows in numpy arrays
    img_prow is the number of images per row.
    '''
    rows = np.ceil(len(images)/img_prow).astype(int)
    fig, (a1) = plt.subplots(rows, img_prow, figsize=(20, 10))
    fig.suptitle(title, size = 50)
    images = images.reshape(len(images), width, length)      
    row_ind = 0
    col_ind = 0
    
    for k in range(len(images)):
        a1[row_ind, col_ind].imshow(images[k,:,:])
        a1[row_ind, col_ind].set_xticklabels([])
        a1[row_ind, col_ind].set_yticklabels([])
        col_ind += 1
        if col_ind > img_prow - 1:
            col_ind  = 0
            row_ind += 1 
    plt.show()
    
plot_images(data.data_train[:10], 5, 28, 28, title = "Missing Data")

# %% [markdown]
# ### Sklearn methods
#
# Let's try some simple methods available in sklearn to compare with our final solution

# %%
from sklearn.impute import SimpleImputer, KNNImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
rec_simple_mean = imp.fit_transform(data.data_train)
plot_images(rec_simple_mean[:10], 5, 28, 28, title = "Imputation SimpleImputer mean")

imp = SimpleImputer(missing_values = np.nan, strategy = "most_frequent")
rec_simple_frequent = imp.fit_transform(data.data_train)
plot_images(rec_simple_frequent[:10], 5, 28, 28, title = "Imputation SimpleImputer most frequent")

rec_knn = KNNImputer(n_neighbors=10, weights="uniform").fit_transform(data.data_train)
plot_images(rec_knn[:10], 5, 28, 28, title = "Imputation KNN Imputer")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [18], line 10
#       7 rec_simple_frequent = imp.fit_transform(data.data_train)
#       8 plot_images(rec_simple_frequent[:10], 5, 28, 28, title = "Imputation SimpleImputer most frequent")
# ---> 10 rec_knn = KNNImputer(n_neighbors=10, weights="uniform").fit_transform(data.data_train)
#      11 plot_images(rec_knn[:10], 5, 28, 28, title = "Imputation KNN Imputer")
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/impute/_knn.py:338, in KNNImputer.transform(self, X)
#     329 # process in fixed-memory chunks
#     330 gen = pairwise_distances_chunked(
#     331     X[row_missing_idx, :],
#     332     self._fit_X,
#    (...)
#     336     reduce_func=process_chunk,
#     337 )
# --> 338 for chunk in gen:
#     339     # process_chunk modifies X in place. No return value.
#     340     pass
#     342 return super()._concatenate_indicator(X[:, valid_mask], X_indicator)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1850, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1848 else:
#    1849     X_chunk = X[sl]
# -> 1850 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1851 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1852     metric, None
#    1853 ) is euclidean_distances:
#    1854     # zeroing diagonal, taking care of aliases of "euclidean",
#    1855     # i.e. "l2"
#    1856     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:2022, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2019         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2020     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2022 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1563, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1560 X, Y, dtype = _return_float_dtype(X, Y)
#    1562 if effective_n_jobs(n_jobs) == 1:
# -> 1563     return func(X, Y, **kwds)
#    1565 # enforce a threading backend to prevent data communication overhead
#    1566 fd = delayed(_dist_wrapper)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:479, in nan_euclidean_distances(X, Y, squared, missing_values, copy)
#     477 XX = X * X
#     478 YY = Y * Y
# --> 479 distances -= np.dot(XX, missing_Y.T)
#     480 distances -= np.dot(missing_X, YY.T)
#     482 np.clip(distances, 0, None, out=distances)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
class dataset(Dataset):
        def __init__(self, X, mask):
            self.X = X
            self.mask = mask
        def __len__(self):
            return len(self.X)   
        def __getitem__(self, idx):
            return self.X[idx], self.mask[idx]

# %% [markdown]
# ### Create the model architecture:
#  - Your AE_module should be able to take any number of hidden layers
#  - You could use the nn.Sequential module of pytorch and get a module that looks as:

# %%
# model.torch_module

# %%
from itertools import pairwise

class AE_module(nn.Module):
    def __init__(self, input_dim, hidden_dims, z_dim):
        super().__init__()
        '''***Complete the init method and the forward pass***
        The input_dim is the number of features of your data
        hidden_dim is a list containing the inner layers dimensions as specified above
        z_dim is the dimension of the bottleneck 
        '''
        
        dims = [input_dim] + hidden_dims + [z_dim]
        encoder_dims = [(a, b) for a, b in pairwise(dims)]
        decoder_dims = [(a, b) for a, b in pairwise(dims[::-1])]
        
        self.encoder = nn.Sequential(
            *[nn.Linear(in_dim, out_dim) for in_dim, out_dim in encoder_dims]
        )

        self.decoder = nn.Sequential(
            *[nn.Linear(in_dim, out_dim) for in_dim, out_dim in decoder_dims]
        )

    def forward(self, x):
        ''' ***Implement the forward pass***
        '''
        x = self.encoder(x)
        x = self.decoder(x)
        return torch.sigmoid(x)

# %%
class AE_MI():
    """Autoencoder for Matrix Imputation"""

    def __init__(self,  lr=1e-3, 
                 epochs=1000, 
                 batch_size=128, 
                 weight_decay=0,
                 hidden_dims=[300, 200, 100], 
                 z_size = 50):
        
        # The learning rate for the optimizer 
        self.lr = lr
        
        # number of epochs and batch size
        self.epochs = epochs
        self.batch_size = batch_size
        self.weight_decay = weight_decay
        
        # dimension of the hidden layers
        self.hidden_dims = hidden_dims  
        # dimension of the bottleneck 
        self.z_size  = z_size   

        '''***define the reconstruction criterion***'''
        self.criterion = nn.MSELoss()

        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    def fit(self, X):
        X = torch.Tensor(X)
        
        # Find zero values to mask to compute the loss
        indices = torch.where(~torch.isnan(X))
        mask_m = torch.zeros(X.shape)
        mask_m[indices[0], indices[1]] = 1
        self.mask = mask_m
        X = torch.nan_to_num_(X)
        


        input_size = X.shape[1]
      
        # Call the AE_module implemented above 
        self.torch_module = AE_module(input_dim=input_size,
                                    hidden_dims=self.hidden_dims,
                                    z_dim=self.z_size)



            
        # define optimizer
        self.optimizer = torch.optim.Adam(self.torch_module.parameters(),
                                          lr=self.lr,
                                          weight_decay=self.weight_decay)
        
        
        
        # Train AE
        self.torch_module.to(self.device)
        self.torch_module.train()
        
        # The dataset class is built with the mask matrix and the data matrix X. 
        data_set = dataset(X, self.mask)
        # Dataloader 
        self.loader = torch.utils.data.DataLoader(data_set, batch_size=self.batch_size, shuffle=False)
        
        
        for epoch in range(self.epochs):
            for batch in self.loader:
                self.optimizer.zero_grad()
                self.train_body(batch)
                self.optimizer.step()
            if epoch % 100 == 0:
                # Just to print the loss and visualize the reconstruction 
                print(f"Epoch {epoch} out of {self.epochs} ==== Loss: {self.loss.item()}")
                rec = self.transform(data.data_train)
                plot_images(rec[:10], 5, 28, 28, title = f"Imputation AE after {epoch} epochs")
                

    def train_body(self, batch):
        data, mask = batch
        mask = mask.to(self.device)
        data = data.to(self.device) 
        x_hat = self.torch_module(data)
        self.apply_loss(data, x_hat, mask)

    def apply_loss(self, x, x_hat, mask):
        '''***Implement the loss***
        '''

        # The loss is computed only on the non-missing values
        mask_inv = 1 - mask
        self.loss = self.criterion(x_hat * mask, x * mask)
        self.loss.backward()

    
    def transform(self, X):
        self.torch_module.eval()
        X = torch.Tensor(np.array(X)).to(self.device)
        X = torch.nan_to_num_(X)
        x_rec = self.torch_module(X)
        self.torch_module.train()
        return x_rec.detach().cpu().numpy()

# %% [markdown]
# ### Now we are ready to create the model and fit it

# %%
model = AE_MI(epochs = 1000, z_size = 100, hidden_dims = [200, 100])
model.fit(data.data_train)
# Out:
# Epoch 0 out of 1000 ==== Loss: 0.026653330773115158
# Epoch 100 out of 1000 ==== Loss: 0.0009846033062785864
# Epoch 200 out of 1000 ==== Loss: 0.0008072851342149079
# Epoch 300 out of 1000 ==== Loss: 0.0007575075142085552
# Epoch 400 out of 1000 ==== Loss: 0.0007097622728906572
# Epoch 500 out of 1000 ==== Loss: 0.0006794602377340198
# Epoch 600 out of 1000 ==== Loss: 0.0006420413265004754
# Epoch 700 out of 1000 ==== Loss: 0.0006722330581396818
# Epoch 800 out of 1000 ==== Loss: 0.0006811341736465693
# Epoch 900 out of 1000 ==== Loss: 0.0006579606560990214

# %% [markdown]
# ### You should get something like this at the end:

# %%
rec = model.transform(data.data_train)
plot_images(rec[:10], 5, 28, 28, title = "Imputation AE")

# %%
'''***Complute the MSE of the reconstruction using data.true_data and the output of the 3 sklearn methods and your AE***
'''

def get_mse_loss(x_hat):
    return nn.functional.mse_loss(torch.Tensor(x_hat), torch.Tensor(data.true_data)).item()

print(f"AE MSE:                   {get_mse_loss(rec)}")
# print(f"KNN MSE:                  {get_mse_loss(rec_knn)}")
print(f"Simple Mean MSE:          {get_mse_loss(rec_simple_mean)}")
print(f"Simple Most Frequent MSE: {get_mse_loss(rec_simple_frequent)}")
# Out:
# AE MSE:                   0.03360458090901375
# Simple Mean MSE:          0.03988289833068848
# Simple Most Frequent MSE: 0.06616027653217316
